# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df1=pd.read_csv("AirPassengers.csv",parse_dates=['Month'],index_col=['Month'])
df1.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# #Passengers    int64
# dtype: object

# %%
df2=df1.rename(columns={'#Passengers':'Pax'})

# %%
df2
# Out:
#             Pax
# Month
# 1949-01-01  112
# 1949-02-01  118
# 1949-03-01  132
# 1949-04-01  129
# 1949-05-01  121
# ...         ...
# 1960-08-01  606
# 1960-09-01  508
# 1960-10-01  461
# 1960-11-01  390
# 1960-12-01  432
#
# [144 rows x 1 columns]

# %%
df2['1951-04-01':'1952-03-01']
# Out:
#             Pax
# Month
# 1951-04-01  163
# 1951-05-01  172
# 1951-06-01  178
# 1951-07-01  199
# 1951-08-01  199
# 1951-09-01  184
# 1951-10-01  162
# 1951-11-01  146
# 1951-12-01  166
# 1952-01-01  171
# 1952-02-01  180
# 1952-03-01  193

# %%
df2.loc['1960-05-01']
# Out:
# Pax    472
# Name: 1960-05-01 00:00:00, dtype: int64

# %%
pip install pylab
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pylab
# ERROR: No matching distribution found for pylab

# %%
from pylab import rcParams
rcParams['figure.figsize']=12,8
df2.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from pylab import rcParams
rcParams['figure.figsize']=12,8
df2.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
mul_decompose=seasonal_decompose(df2,model='multiplicative')
mul_decompose.plot()
plt.show()

# %%
df2_log=df2.copy()

# %%
df2_log['Pax']=np.log(df2)

# %%
df2_log.Pax
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
#                 ...
# 1960-08-01    6.406880
# 1960-09-01    6.230481
# 1960-10-01    6.133398
# 1960-11-01    5.966147
# 1960-12-01    6.068426
# Name: Pax, Length: 144, dtype: float64

# %%
df2_log.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.subplot(2,1,1)
plt.title('orignal time_series')
plt.plot(df2)

plt.subplot(2,1,2)
plt.title('time_series after log')
plt.plot(df2_log)
